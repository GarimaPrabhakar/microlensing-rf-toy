# %%
from utils import adjacency_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 50)
f = 2000*(np.random.random(size=len(t))-0.5) + 3000

# %%
plt.scatter(t, f)

# %%
_, _, am = adjacency_matrix(4, f, t)

# %%
plt.imshow(am)
plt.colorbar()
