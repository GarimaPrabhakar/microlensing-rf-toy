# %%
import pandas as pd

# %%
# !conda install scikit-learn --y
cols = []
cols.append('fn')
cols.append('event')
cols.append('tE')
cols.append('t0')
cols.append('u0')
for i in range(49):
    cols.append(i)

# %%
dfml = pd.read_csv("trainingset/microlensing.csv", names=cols)
dfmlnot = pd.read_csv("trainingset/not_microlensing.csv", names=cols)

dfml["target"] = 1
dfmlnot["target"] = 0

df = pd.concat([dfml, dfmlnot], axis=0)
df
# Out:
#                                                      fn
# 0     ../Crowdsourcecopy/crowdsource/crowdsource/csd...  \
# 1     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 2     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 3     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 4     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# ...                                                 ...
# 9595  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9596  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9597  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9598  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9599  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
#
#                       event   tE   t0    u0             0            1
# 0                   mlevent  232   77  0.68      0.010978     0.013059  \
# 1        noise_mlevent_orig    0    0  0.00    294.401480   265.382921
# 2         noise_mlevent_new  132   49  0.11    294.401480   466.089821
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN
df.dropna(inplace=True)
display(df)
df.dropna().iloc[np.where(x.dropna()==np.inf)]
# Out:
#                                                      fn
# 0     ../Crowdsourcecopy/crowdsource/crowdsource/csd...  \
# 1     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 2     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 3     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 4     ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# ...                                                 ...
# 9595  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9596  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9597  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9598  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
# 9599  ../Crowdsourcecopy/crowdsource/crowdsource/csd...
#
#                       event   tE   t0    u0             0            1
# 0                   mlevent  232   77  0.68      0.010978     0.013059  \
# 1        noise_mlevent_orig    0    0  0.00    294.401480   265.382921
# 2         noise_mlevent_new  132   49  0.11    294.401480   466.089821
# ...

# %%
x = df.drop(['target', 'fn', 'tE', 't0', 'u0', 'event'],axis='columns')
y = df["target"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)

# %%
import numpy as np
np.where(x==np.max(np.array(x)))
# Out:
# (array([ 1124,  1125,  1126,  1127,  1127,  1320,  1321,  1322,  1323,
#          1323,  1696,  1696,  1697,  1697,  1697,  1697,  1697,  1697,
#          1697,  1697,  1697,  1697,  1697,  1697,  1697,  1697,  1697,
#          1698,  1698,  1698,  1698,  1698,  1698,  1698,  1698,  1698,
#          1698,  1698,  1698,  1698,  1698,  1698,  1698,  1698,  1699,
#          1699,  1699,  1699,  1699,  1699,  1699,  1699,  1699,  1699,
#          1699,  1699,  1952,  1952,  1953,  1953,  1953,  1953,  1953,
#          1953,  1953,  1953,  1953,  1953,  1953,  1953,  1953,  1954,
#          1954,  1954,  1954,  1954,  1954,  1954,  1954,  1954,  1954,
#          1954,  1955,  1955,  1955,  1955,  1955,  1955,  1955,  1955,
#          1955,  1955,  1955,  1955,  7952,  7953,  7954,  7955,  7964,
#          7965,  7965,  7966,  7966,  7967,  8064,  8065,  8065,  8066,
#          8066,  8067,  8067,  8580,  8581,  8581,  8582,  8582,  8583,
# ...

# %%
x.iloc[np.where(x==np.max(np.array(x)))]
# Out:
#               36          21          21          8            22          36
# 1124         inf   36.993248   36.993248    0.002611    32.056183         inf  \
# 1125    0.000000         inf         inf    0.000000     0.000000    0.000000
# 1126    0.000000         inf         inf    0.000000     0.000000    0.000000
# 1127    0.000000  174.351343  174.351343         inf          inf    0.000000
# 1127    0.000000  174.351343  174.351343         inf          inf    0.000000
# ...          ...         ...         ...         ...          ...         ...
# 7550         inf   68.247200   68.247200  434.484290   276.797426         inf
# 8574  137.387038  385.817062  385.817062  265.469030   265.388143  137.387038
# 8574  137.387038  385.817062  385.817062  265.469030   265.388143  137.387038
# 8575    0.000000    0.000000    0.000000    0.000000     0.000000    0.000000
# 8576    0.005762  239.788345  239.788345  180.508991  1030.368537    0.005762
#
# ...

# %%
x.dropna().iloc[np.where(x.dropna()==np.inf)]
# Out:
#               36          21          21          8            22          36
# 1124         inf   36.993248   36.993248    0.002611    32.056183         inf  \
# 1125    0.000000         inf         inf    0.000000     0.000000    0.000000
# 1126    0.000000         inf         inf    0.000000     0.000000    0.000000
# 1127    0.000000  174.351343  174.351343         inf          inf    0.000000
# 1127    0.000000  174.351343  174.351343         inf          inf    0.000000
# ...          ...         ...         ...         ...          ...         ...
# 7550         inf   68.247200   68.247200  434.484290   276.797426         inf
# 8574  137.387038  385.817062  385.817062  265.469030   265.388143  137.387038
# 8574  137.387038  385.817062  385.817062  265.469030   265.388143  137.387038
# 8575    0.000000    0.000000    0.000000    0.000000     0.000000    0.000000
# 8576    0.005762  239.788345  239.788345  180.508991  1030.368537    0.005762
#
# ...

# %%
x.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN
x.dropna(inplace=True)
display(x)
x.dropna().iloc[np.where(x.dropna()==np.inf)]
# Out:
#                 0            1            2            3            4
# 0         0.010978     0.013059     0.006530     0.000000     0.034539  \
# 1       294.401480   265.382921   805.846538   720.983166   443.429594
# 2       294.401480   466.089821  1192.811334   133.311470     0.000000
# 3       592.712838     0.000000   309.582773    51.232820   405.945592
# 4         0.350323     0.228291    59.388907   117.989613     0.155518
# ...            ...          ...          ...          ...          ...
# 9595  69408.767823   839.299170     6.079146     0.000000     0.000000
# 9596   2300.686065  1761.752192  2417.018917  1343.422608  1892.121514
# 9597   2192.139096   829.139174  2227.923789  1850.079788  1735.404358
# 9598      3.842614     3.643119  1807.132016     5.502333     4.708951
# 9599   3062.180833  1338.815978  2343.693608  2385.322921  1326.002886
#
#                5            6            7            8            9   ...
# ...

# %%
x.dropna().iloc[np.where(x.dropna()==np.inf)]
# Out:
# Empty DataFrame
# Columns: []
# Index: []
